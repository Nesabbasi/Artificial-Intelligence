# %%
import pandas as pd 
from IPython.display import HTML

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")
train_data
# Out:
#             label                                            content
# 0          فناوری  گزارش های منتشر شده حاکی از آن است که کاربران ...
# 1           ورزشی  سوپر استار سینما و از قهرمانان سابق ووشو ــ کو...
# 2           حوادث  مدیرعامل شرکت عمران آب کیش از فوت یک نفر در آت...
# 3          فناوری  یک نوجوان انگلیسی به اتهام هک حساب‌های کاربری ...
# 4           سلامت  دانشمندان در جدیدترین مطالعات خود اثرات جدید و...
# ...           ...                                                ...
# 8995        حوادث  شانزدهم مهر امسال درپی تماس با مرکز فوریت‌های ...
# 8996        ورزشی  اتحادیه فوتبال ترینیداد و توباگو اعلام کرده تی...
# 8997  فرهنگی/هنری  اسامی 18 فیلم بخش مسابقه مستند ششمین دوره جشنو...
# 8998        حوادث  کامیونت حامل بار تخته‌های چوبی عصر دیروز چهارش...
# 8999       فناوری  چهارمین لیگ بازی‌های رایانه‌ای ایران از روز ۶ ...
#
# [9000 rows x 2 columns]

# %%
from __future__ import unicode_literals
from hazm import *

normalizer = Normalizer()
stemmer = Stemmer()
lemmatizer = Lemmatizer()

# %%
labels = train_data['label'].unique()
labels
# Out:
# array(['فناوری', 'ورزشی', 'حوادث', 'سلامت', 'سیاسی', 'فرهنگی/هنری'],
#       dtype=object)

# %%
labels_frequency = train_data['label'].value_counts()
labels_frequency
# Out:
# فناوری         1500
# ورزشی          1500
# حوادث          1500
# سلامت          1500
# سیاسی          1500
# فرهنگی/هنری    1500
# Name: label, dtype: int64

# %% [markdown]
# <font size=4 color='#FFFFFF'> 1. Preprocessing Data<font>
#
# <font size=2 color='#FFFFFF'> In this section we clean data by using Normalizer, Stemmer and Lemmatizer.<font>

# %%
normalizer = Normalizer()
stemmer = Stemmer()
lemmatizer = Lemmatizer()

# %% [markdown]
# <font size=2 color='#FFFFFF'> -> Normalizer is an option which replacing space with half space. <font>

# %%
normalizer.normalize ( 'اصلاح نویسه ها و استفاده از نیم فاصله پردازش را آسان می کند' )
# Out:
# 'اصلاح نویسه\u200cها و استفاده از نیم فاصله پردازش را آسان می\u200cکند'

# %% [markdown]
# <font size=2 color='#FFFFFF'> -> Stemmer chops off letters from the end until the stem is reached <font>

# %%
print(stemmer.stem('آمدم'))
print(stemmer.stem('آمدی'))
print(stemmer.stem('آمدند'))
print(stemmer.stem('آمدیم'))
print(stemmer.stem('آمدید'))
# Out:
# آمد
# آمد
# آمدند
# آمد
# آمدید

# %% [markdown]
# <font size=2 color='#FFFFFF'> -> Lemmatizer is an option which gives the Bon(Maazi or Mozare) of the verbs. <font>

# %%
print(lemmatizer.lemmatize('خوردم'))
print(lemmatizer.lemmatize('خوردی'))
print(lemmatizer.lemmatize('خوردند'))
print(lemmatizer.lemmatize('خوردیم'))
print(lemmatizer.lemmatize('خوردید'))
# Out:
# خورد#خور
# خورد#خور
# خورد#خور
# خورد#خور
# خورد#خور

# %%
def clean_data(is_normalize, is_stem, is_lemmatize, text):
    if is_normalize:
        text = normalizer.normalize(text)
    if is_stem:
        text = map(stemmer.stem, text)
    if is_lemmatize:
        text = map(lemmatizer.lemmatize, text)
    return text

# %% [markdown]
# <font size=2 color='#FFFFFF'>In this function we open the text file and replace the half space to space and add ['\n' , '\r'] to file. Also lemmatize words and return it.<font>

# %%
def get_stop_words(file_name):
    with open(file_name, encoding="utf-8") as f:
        stop_words = [word.replace('\u200c',' ').strip() for word in f]
    stop_words.extend(['\n', '\r', '\xa0'])
    stop_words = clean_data(is_normalize=False, is_stem=False, is_lemmatize=True, text=stop_words)
    return set(stop_words)

# %%
stop_words = get_stop_words('stop_words.txt')
stop_words
# Out:
# {'مخصوصاً',
#  'آسان',
#  'خالصانه',
#  'درحالیکه',
#  'محکم تر',
#  'آزادانه',
#  'همچنان که',
#  'طی',
#  'دونستن',
#  'ساله',
#  'وقتی که',
#  'ازاین رو',
#  'واما',
#  'جناح',
#  'آباد',
#  'جمع',
#  'گو',
#  'بازی کنان',
#  'یکدیگر',
#  'خودم',
#  'هنگام',
#  '؟',
#  'نمی کند',
#  '\ufeffو',
#  'او',
#  'عه',
#  'عمداً',
#  'بی هدف',
#  'وگو',
#  'وقتیکه',
#  'بد',
#  'خویشتن',
#  'طلبکارانه',
#  'ق',
#  'گویا',
#  'تعمدا',
#  'قطعا',
#  'دسته دسته',
#  'گرفته',
#  'خویش',
#  'لذا',
#  'ثانیاً',
#  '\\xa0',
#  'مع الاسف',
#  'اینگونه',
#  'مثل',
#  'بردار',
#  'زشتکارانند',
#  'سر',
#  'ش',
#  'عموم',
#  'همگی',
#  'سالهاست',
#  'به قدری',
#  'خلاصه',
#  'زیرچشمی',
#  'گونه',
#  'ایند',
#  'خصوصاً',
#  'نباید',
#  'همواره',
#  'کن',
#  'عرفان',
#  'برایشان',
#  'به طور کلی',
#  'حاضر',
#  'وجود',
#  'پیداست',
#  'کرده',
#  'امسال',
#  'محتاجند',
#  'مگر آن که',
#  'درون',
#  'علاوه برآن',
#  'بتدریج',
#  'تعداد',
#  'داام',
#  'کاملا',
#  'درست',
#  'بهتر',
#  'حضرتعالی',
#  'اکثریت',
#  'هایی',
#  'به خوبی',
#  'به سرعت',
#  'یقیناً',
#  'هیچکدام',
#  'چته',
#  'بالاخص',
#  'بعضا',
#  'باز هم',
#  'سعی',
#  'ّه',
#  'امیدوار',
#  'یا',
#  'داد#ده',
#  'به کرات',
#  'وحشت زده',
#  'انشاالله',
#  'اخیراً',
#  'درمجموع',
#  'گرفتارند',
#  ')',
#  'آی',
#  'ناامید',
#  'تا',
#  'روم',
#  'مشترکاً',
#  'یک کم',
#  ',',
#  'زه',
#  'میفرستین',
#  'اینطور',
#  'از آن پس',
#  'تنها',
#  'بدین',
#  'لزوماً',
#  'بخصوص',
#  'ملیارد',
#  'تریلیون',
#  '۳',
#  'اولین',
#  'واقعاً',
#  'البتّه',
#  'کو',
#  'پیشتر',
#  'اقلیت',
#  'نوع',
#  'کردی',
#  'بیش',
#  'اندک',
#  'روی',
#  'آنطور',
#  'شخصاً',
#  'امشب',
#  'مقابل',
#  'ضمناً',
#  'آنقدر',
#  'همه شان',
#  'نظیر',
#  'بی تفاوتند',
#  'به تازگی',
#  'هنوز',
#  'چطور',
#  'آنهاست',
#  'های',
#  'حقیقتا',
#  'اینچنین',
#  'کاشت#کار',
#  'وابسته اند',
#  'کل',
#  'شش',
#  'حاشیه ای',
#  'سراپا',
#  'ب',
#  'مخالفند',
#  '*',
#  'عاقبت',
#  'همزمان',
#  'به',
#  'کماکان',
#  'بروز',
#  'ل',
#  'معتقد',
#  'نموده',
#  'به زودی',
#  'کنون',
#  'بخش',
#  'اونجور',
#  'دااما',
#  'پیدا',
#  'مان',
#  'مجدداً',
#  'اونجوری که',
#  'صرفاً',
#  'دایما',
#  'محض رضای خدا',
#  'فقط',
#  'نداری',
#  'بازیگوشانه',
#  'اش',
#  'گرفت#گیر',
#  'ویا',
#  'آنچنان که',
#  'شی',
#  'کدام',
#  'اصولا',
#  'هیچکس',
#  'ناشی',
#  'جز',
#  'با',
#  'بالایِ',
#  'بعد',
#  'ناگزیر',
#  'چه',
#  'مثلا',
#  'هم اینک',
#  'آنچه',
#  'داشت#دار',
#  'ماند#مان',
#  'داخل',
#  'داد',
#  'خیلی',
#  'چکار',
#  'جمعا',
#  'نهایتا',
#  'حتماً',
#  'جور',
#  'آدمهاست',
#  'حقیرانه',
#  'رهگشاست',
#  'موارد',
#  'مجموعاً',
#  'هبچ',
#  'قانوناً',
#  'همچنین',
#  'چنین',
#  '۸',
#  'شد#شو',
#  'امروزه',
#  'اله',
#  'علی رغم',
#  '،',
#  'هیچگاه',
#  'به ویژه',
#  'زیاده',
#  'علّتِ',
#  'می خوانم',
#  'زیرا',
#  '«',
#  'همگان',
#  'اگه',
#  'ازجمله',
#  'سرانجام',
#  'می رسد',
#  'عنوان',
#  'برابر',
#  'آنکه',
#  'ی',
#  'خودمو',
#  'عملی اند',
#  'نوعاً',
#  'توؤماً',
#  'سابق',
#  'اینو',
#  'مثلِ',
#  'می خواهیم',
#  'باورند',
#  'عجولانه',
#  'هستش',
#  'امیدوارند',
#  'آنجا',
#  'علناً',
#  'بهتون',
#  'یافتن',
#  'بعلاوه',
#  'کننده',
#  'تو',
#  'طبعاً',
#  'قابل',
#  'متفاوتند',
#  'علاوه بر آن',
#  'دم',
#  'هر',
#  'پیشِ',
#  'احیاناً',
#  'شان',
#  'پنج',
#  'چنانچه',
#  'رشته',
#  'کما\x7fاینکه',
#  'مجموعا',
#  'بعداً',
#  'در واقع',
#  'امور',
#  'اما',
#  'تماما',
#  'میفرستم',
#  'ثانیا',
#  'قاطعانه',
#  'داشت',
#  'اصلا',
#  'صندوق هاست',
#  'شیرینه',
#  'باز',
#  'بشید',
#  'واقعی',
#  'خارجِ',
#  'سریعا',
#  'ای',
#  'غالبا',
#  'بخشی',
#  'آنانی',
#  'در کل',
#  '۶',
#  'ناگاه',
#  'واقعا',
#  'آور',
#  'بود#باش',
#  'بعضی شان',
#  'این گونه',
#  '.',
#  'حداقل',
#  'سالیانه',
#  'پایین ترند',
#  'پشیمونی',
#  'چیز',
#  'فاقد',
#  'جدا',
#  'انطور',
#  'برایم',
#  'حتما',
#  'پریروز',
#  'رواست',
#  'پس فردا',
#  'آیا',
#  'حق',
#  'اکثرا',
#  'نخست',
#  'ج',
#  'فر',
#  'بی اطلاعند',
#  'به وضوح',
#  'سو',
#  'تحت',
#  'قضایاست',
#  '#هست',
#  'پهن شده',
#  'انتها',
#  'انگار',
#  'خوشبختانه',
#  'ع',
#  'کاش',
#  'داشتن',
#  'آن',
#  'هرگاه',
#  'میکنید',
#  'هیچ',
#  'شخصا',
#  'معلومه',
#  'بیرون',
#  'چند',
#  'مدتهاست',
#  'بخشه',
#  'تویِ',
#  'همه',
#  'بسختی',
#  'پیش',
#  'خداروشکر',
#  'از',
#  'اینان',
#  '-',
#  'عمدا',
#  'بی آنکه',
#  'می خوانید',
#  '\u200f\u200f\u200fعلاقه مند',
#  'خب',
#  'گیر',
#  'صددرصد',
#  'هنگامی',
#  'از جمله',
#  '!',
#  'عدم',
#  'چندان',
#  'رفتارهاست',
#  'بشم',
#  'یک جوری',
#  'حتی',
#  'بیگمان',
#  'هق هق کنان',
#  'یکریز',
#  'میلیارد',
#  'توانستن',
#  'مارو',
#  'سخت',
#  'قبلاً',
#  'می کنم',
#  'ص',
#  'جدیدا',
#  'مکرراً',
#  'برایش',
#  'بهترین',
#  'به جز',
#  'عاجزانه',
#  'عنوانِ',
#  'اری',
#  'گهگاه',
#  'یواش یواش',
#  'اتفاقا',
#  'نزدیکِ',
#  'اولاً',
#  'دیر',
#  'بهت',
#  'نداشته',
#  'غ',
#  '۲',
#  'آری',
#  '#است',
#  'واقفند',
#  'شدیدا',
#  'شیرین',
#  'می',
#  'دوم',
#  'کی',
#  'دفعه',
#  'بویژه',
#  'بیرونِ',
#  'روز به روز',
#  'بدین ترتیب',
#  'روزه ست',
#  'سریع',
#  'میکند',
#  'می تواند',
#  'نواند',
#  'همچون',
#  'می شود',
#  'به شان',
#  'حضور',
#  'اگرچه',
#  'بگین',
#  'دقیقا',
#  'کرد#کن',
#  'تریلیارد',
#  'پیرامون',
#  'استفاد',
#  'مرا',
#  'سه باره',
#  'خود',
#  'الی',
#  'متاسفانه',
#  'پشتوانه اند',
#  'به تدریج',
#  'ضدِّ',
#  '۱',
#  'تقریباً',
#  'نبش',
#  'مدت',
#  'کاشکی',
#  'اند',
#  'به رغم',
#  'تحریم هاست',
#  'بسیار',
#  'اون',
#  'میان',
#  '/',
#  'راسا',
#  'همان',
#  'منطق',
#  '۵',
#  'اگر چه',
#  'رفت#رو',
#  'روز',
#  'به درشتی',
#  'ماست',
#  'معمولا',
#  'هرچه',
#  'طبعا',
#  'عیناً',
#  'هم اکنون',
#  'جنابعالی',
#  'مامان مامان گویان',
#  'سمتِ',
#  'مرسی',
#  'هر چند',
#  'بزرگ',
#  'مدام',
#  'روب',
#  'گه',
#  'درین',
#  'خواستن',
#  'در باره',
#  'ث',
#  'چت',
#  'ط',
#  'به آسانی',
#  'دیده',
#  'گاه',
#  'علیرغم',
#  'ز',
#  'فعلا',
#  'چه طور',
#  'درعین حال',
#  'اثرِ',
#  'ممیزیهاست',
#  'همین',
#  'کمتر',
#  'رسید',
#  'آمد#آ',
#  'برا',
#  'باره',
#  'معذور',
#  'اساساً',
#  'بشدت',
#  'به علاوه',
#  'دام',
#  'ر',
#  'چنده',
#  'کلا',
#  'چیزیست',
#  'چاپلوسانه',
#  ':',
#  'بااین حال',
#  'بعضی',
#  'اینجا',
#  'باوجودی که',
#  'بی نیازمندانه',
#  'تک تک',
#  'یعنی',
#  'حدود',
#  'موجودند',
#  'چ',
#  'جلو',
#  'سالم تر',
#  'ساخته',
#  'مجددا',
#  'کم کم',
#  'اینکه',
#  'کند',
#  'به شدت',
#  'گوی',
#  'پاره ای',
#  'دیروز',
#  'پاعینِ',
#  'بدون',
#  'چون',
#  'میلیون',
#  'همانا',
#  'ملیون',
#  'مگر',
#  'شاهدند',
#  'برآنند',
#  'حال',
#  'بیست',
#  'بلافاصله',
#  'هرکس',
#  'بروشنی',
#  'عموماً',
#  'ن',
#  'سهواً',
#  'پارسال',
#  'معمولی',
#  'پس از',
#  'کنار',
#  'نخستین',
#  'تولِ',
#  'بوده',
#  'دیگه',
#  'سالته',
#  'دریغا',
#  'چی',
#  'کلی',
#  'ترین',
#  'خیاه',
#  'جرمزاست',
#  'در آینده',
#  'هیچ جور',
#  'روزانه',
#  'طرف',
#  'دهم',
#  'شش نداشته',
#  'ریخت#ریز',
#  'خصوصا',
#  'تان',
#  'برنامه سازهاست',
#  'چنانکه',
#  'کنارِ',
#  'تقریبا',
#  'شو',
#  '…',
#  'مگر این که',
#  'ک',
#  'گرفتن',
#  'شناخت#شناس',
#  'بالاخره',
#  'بالعکس',
#  'منی',
#  'عجب',
#  'تمام قد',
#  'قبلا',
#  'هیچگونه',
#  'لطفا',
#  'به سادگی',
#  'داشته',
#  'بااین وجود',
#  'همه مون',
#  'جداگانه',
#  'هام رو',
#  'در ثانی',
#  'شاید',
#  'این',
#  'ایم',
#  'دیوانه ای',
#  'به هیچ وجه',
#  'ه',
#  'اسلامی اند',
#  'بدان',
#  'طریق',
#  'از بس که',
#  'ساکنند',
#  'بعری',
#  'حول',
#  'به تمامی',
#  'مقصر',
#  'روزه ایم',
#  'زیر',
#  'شونده',
#  'خوش',
#  'زیاد',
#  'خوب',
#  'مطمانم',
#  'پروردگارا',
#  'کم',
#  'راه',
#  'انجام',
#  'نگاه',
#  'نیز',
#  'قاعدتاً',
#  'وجدانا',
#  'جای',
#  'وقت',
#  'می رود',
#  'یک کمی',
#  'صریحاً',
#  'توانی',
#  'برخی',
#  'توان',
#  'تلویحا',
#  'روش',
#  'همدیگر',
#  'انصافا',
#  'می کنند',
#  'کلیه',
#  'بطور',
#  'تند تند',
#  'چگونه',
#  'داراست',
#  'مانند',
#  'درحالی که',
#  'هر چند که',
#  'یک',
#  'کسانی',
#  'دو روزه',
#  'قدر',
#  'وضع',
#  'راحت',
#  'رفته',
#  'معدود',
#  'عملاً',
#  'نفرند',
#  'همچنان',
#  'آن ها',
#  'جریان',
#  'به هرحال',
#  'دا',
#  'فردا',
#  'ا',
#  'افزود#افزا',
#  'درواقع',
#  'آشنایند',
#  'ژ',
#  'برعکس',
#  'سری',
#  'داره',
#  'اینجاست',
#  'اونجوری',
#  'رسما',
#  'ناخواسته',
#  'طور',
#  'آقا',
#  'احتراما',
#  'جنس اند',
#  'همیشه',
#  'آنچنان',
#  'انها',
#  '\n',
#  'مشت',
#  'راجع به',
#  'نیم',
#  'میخونید',
#  'دو',
#  'سویِ',
#  'بلکه',
#  'میخوانید',
#  'جا',
#  'این قدر',
#  'آشکارا',
#  'مدّت',
#  'مغرضانه',
#  'نه تنها',
#  'مستحضرید',
#  'پشت',
#  'هرچند',
#  'شوم',
#  'اقل',
#  'ام',
#  'برخوردار',
#  'بس',
#  'ف',
#  'اخیر',
#  'بطوری که',
#  'همه اش',
#  'ویژه',
#  'سوم',
#  'زیرِ',
#  'خودتو',
#  'باید',
#  'دشمن',
#  'زود',
#  'میکنم',
#  'الان',
#  'چقدر',
#  'چهار',
#  '۷',
#  'بلی',
#  'آورد#آور',
#  'البته',
#  'خیر',
#  'ممکن',
#  'نشان',
#  'خداست',
#  'ولی',
#  'درسته',
#  'علی الظاهر',
#  'خ',
#  'مواجهند',
#  'دیو',
#  'نخود',
#  'کاملاً',
#  'هیچوقت',
#  '۹',
#  'اوست',
#  'هیچ گاه',
#  'جلوگیری',
#  'آهای',
#  'درست و حسابی',
#  'به مراتب',
#  'شیک',
#  'شمرد#شمار',
#  'نم',
#  'مطمینا',
#  'بالطبع',
#  '\r',
#  'موقتا',
#  'ساده اند',
#  'غیرقانونی',
#  'مردانه',
#  'هیچجور',
#  'یافت#یاب',
#  'روزه ای',
#  'شوق',
#  'میزان',
#  'اولا',
#  'اعلام',
#  'رو',
#  'در بارهٌ',
#  'ایا',
#  'امروز',
#  'می داند',
#  'براساس',
#  'کتبا',
#  'ما رو',
#  'خواه',
#  'ناگهان',
#  'مثل اینکه',
#  'خسته ای',
#  'در کنار',
#  'هزار',
#  'برخوردارند',
#  'مفیدند',
#  'ظاهرا',
#  'اینهاست',
#  'اول',
#  'آخر',
#  'سیاه چاله هاست',
#  'محکم',
#  'نمی شود',
#  'به راستی',
#  'ناراضی اند',
#  'اصولاً',
#  'زمینه',
#  'فلان',
#  'مختلف',
#  'کمتره',
#  'ثالثاً',
#  'کجاست',
#  'گروهی',
#  '[',
#  'آره',
#  'خیره',
#  'بعضی ها',
#  'حدودِ',
#  'سازی',
#  'مکرر',
#  'ت',
#  'صد',
#  'بنابراین',
#  'ان',
#  'اینقدر',
#  'دیشب',
#  'ها',
#  'را',
#  'تاکنون',
#  'باد',
#  ']',
#  'و',
#  'نیست',
#  'توانست#توان',
#  '(',
#  'بست#بند',
#  'درباره',
#  'اکنون',
#  'مانندِ',
#  'فوق',
#  'بر',
#  'بدانجا',
#  'اینک',
#  'به جای',
#  'هر از گاهی',
#  'دراین میان',
#  'دوباره',
#  'چه بسا',
#  'چو',
#  'روزه م',
#  'چشم بسته',
#  'حسابگرانه',
#  'حاکیست',
#  'شما',
#  'همین که',
#  'پ',
#  'افسوس',
#  'چرا که',
#  '\xa0',
#  'سخته',
#  'سراسر',
#  'بی',
#  'گذاشته',
#  'هنگامِ',
#  'جمع اند',
#  'مستند',
#  'پدرانه',
#  '"',
#  'عقبِ',
#  'عمدتاً',
#  'اکثراً',
#  'پی',
#  'خود به خود',
#  'چرا',
#  'قبل',
#  'قصدِ',
#  'کجا',
#  'بودن',
#  'وی',
#  'قطعاً',
#  'به گرمی',
#  'آرام آرام',
#  'تصریحاً',
#  'یکهزار',
#  'س',
#  'هامو',
#  'آنگاه',
#  'جداً',
#  'من',
#  'هرگز',
#  'هنگامی که',
#  'بار',
#  'یه',
#  'عموما',
#  'خودش',
#  'به دلخواه',
#  '۰',
#  'همهٌ',
#  'دادن',
#  'انچنان',
#  'خواست#خواه',
#  'اغلب',
#  'انکه',
#  'ح',
#  'د',
#  'ضمن',
#  'ض',
#  'عملا',
#  'هوی',
#  'درصورتی که',
#  'هی',
#  'برایمان',
#  'وگرنه',
#  'اشکارا',
#  'مقصرند',
#  'چیه',
#  'زد#زن',
#  'پرسان',
#  'لیکن',
#  'در مجموع',
#  'برایِ',
#  'روبروست',
#  'لب',
#  'حکماً',
#  'لطفاً',
#  'علاوه بر',
#  'همچین',
#  'رویش',
#  'همان طور که',
#  'زمان',
#  'تر براساس',
#  'همانند',
#  'همه ساله',
#  'تمام',
#  'آمدن',
#  'غزال',
#  'مادامی',
#  'کَی',
#  'مشغولند',
#  'ان شاأالله',
#  'مذهبی اند',
#  'دریغ',
#  'بعدا',
#  'در',
#  'مردم اند',
#  'میکنیم',
#  'بالاست',
#  'بیفته',
#  'شدیداً',
#  'غیر',
#  'هستا',
#  'خدمات',
#  'وای',
#  'بجز',
#  'پارسایانه',
#  'رنجند',
#  'دانست#دان',
#  'بدجور',
#  'بعید',
#  'میکنی',
#  'یاب',
#  'برنامه',
#  'در نهایت',
#  'عنقریب',
#  'بازه',
#  'طبیعتا',
#  'عمده',
#  'گفت#گو',
#  'ده',
#  'دیگر',
#  'بسادگی',
#  'معمولاً',
#  'استفاده',
#  'کردن',
#  'پیشاپیش',
#  'هستی',
#  'فلذا',
#  'هم',
#  'تلویحاً',
#  'انقدر',
#  'خودبه خودی',
#  'قاالند',
#  'مطمانا',
#  '٪',
#  'بشین',
#  'بین',
#  'که',
#  'متعاقبا',
#  '؛',
#  'کس',
#  '#',
#  'اگر',
#  'میکنند',
#  'پس',
#  'یک چیزی',
#  'ظ',
#  'گ',
#  'دنبالِ',
#  'به ناچار',
#  'خداحافظ',
#  'جهت',
#  'صورت',
#  'نیازمندند',
#  'شاهد',
#  'گرچه',
#  'راست',
#  'مبادا',
#  'چندین',
#  'گذشته',
#  'اساسا',
#  'نام',
#  'جلویِ',
#  'مستقیما',
#  'توسط',
#  'گشت#گرد',
#  'بالا',
#  'اکثر',
#  'آورده',
#  'سریِ',
#  'نمود#نما',
#  'معتقدند',
#  'شون',
#  'رسیده',
#  'اشتباها',
#  'بی تردید',
#  'بارة',
#  'رویِ',
#  ...}

# %% [markdown]
# <font size=2 color='#FFFFFF'> In the preprocess function, cleaning the content of each row by repalcing the half space with space and then normalize the data. Also seprate words by using the word_tokenize and lemmatize words. And before return the data, check if word is not in stop_words.<font>

# %%
def preprocess(data):
    change_halfspace = data.replace('\u200c', ' ')
    normalized_data = clean_data(is_normalize=True, is_stem=False, is_lemmatize=False, text=change_halfspace)
    words = word_tokenize(normalized_data)
    words = clean_data(is_normalize=False, is_stem=False, is_lemmatize=True, text=words)
    new_words = []
    for word in words:
        if word not in stop_words:
            new_words.append(word)
    return new_words

# %%
preprocess(train_data['content'][0])
# Out:
# ['گزارش',
#  'منتشر',
#  'حاکی',
#  'کاربر',
#  'تلگرام',
#  'مناطق',
#  'جهان',
#  'اروپا',
#  'خاورمیانه',
#  'مشکل',
#  'مواجه',
#  'گزارش',
#  'ایسنا',
#  'نقل',
#  'تلگرام',
#  'دقایق',
#  'پیام',
#  'رس',
#  'تلگرام',
#  'صفحه',
#  'دسترس',
#  'کاربر',
#  'اپلیکیشن',
#  'اروپا',
#  'خاورمیانه',
#  'مشکل',
#  'مواجه',
#  'طبق',
#  'پیام',
#  'نظر',
#  'رسید#رس',
#  'منشا',
#  'اختلالات',
#  'ظهر',
#  'شنبه',
#  'خارج',
#  'پیام',
#  'رس',
#  'ارتباط',
#  'کشور',
#  'پیام',
#  'رس',
#  'خصوص',
#  'متخصص',
#  'تلگرام',
#  'متوجه',
#  'اختلال',
#  'بررسی',
#  'برطرف',
#  'مشکل',
#  'مربوطه',
#  'امید',
#  'اختلال',
#  'رفع',
#  'کاربر',
#  'حساب',
#  'کاربر',
#  'تلگرام',
#  'دسترس']

# %% [markdown]
# <font size=4 color='#FFFFFF'> 2. Problem Process <font>
#
# <font size=2 color='#FFFFFF'>
#
# Start with base formula used in Naive bayed classifier:
#
# $$ P(c|x) = \frac{P(x|c)P(c)}{P(x)} $$
#
# $x$: The word detected
#
# $c$: Lable
#
# $P(x|c)$ : Probability of seeing word $x$ in a content of type $c$.
# (Likelihood)
#
# $P(c|x)$ : Probability of the label $c$ knowing that the word $x$ has appeared in the context. (Posterior Probability)
#
# $P(c)$: Probability of labeling as label $c$ which is equal for all labels since they all have occured the same number of times in the dataset. (Class Prior Probability)
#
# We don't need to calculate $P(x)$ since it's common in all probabilities, and as mentioned before $P(c)$ is equal for all labels.
# Also since we may have $n$ words in the content, $X$ can be represented as $(x_1, x_2, ..., x_n)$. So the probability can be calculated as follows:
#
# $$ P(c|x) = {P(x_1|c)P(x_2|c) ... P(x_n|c)P(c)} $$
# <font>

# %% [markdown]
# <font size=4 color='#FFFFFF'> 2.1 Bigram<font>
#
# <font size=2 color='#FFFFFF'>
#
# Using N-grams besides increasing the amount of information captured from context, might increase accuracy.
#
#
# Using *Unigrams* when we consider a word by itself without paying attention to the words before/after it.
#
# Using *Bigrams* when we consider a sequence of two adjacent elements.
#
# This is en example which bigrams become useful:
#
# بعد از خوردن غذا سیر شدم.
#
# من سیر دوست ندارم.
#
# In the first sentence, سیر means Full but in the second example it means Garlic. Therefore, these two sentences have different concepts. First sentence translates to "I was full after eating" and the second one translates to "I don't like garlic".
#
#
# <font>

# %%
def make_ngrams(words, n=1):
    ngrams = []
    for i in range(len(words) - n + 1):
        ngrams.append(' '.join(words[i:i+n]))
    return ngrams

# %% [markdown]
# <font size=2 color='#FFFFFF'> To check the correctness of the model, we plot the words frequency for each label.<font>

# %%
def fit(n=1):
    total_data = {label:0 for label in labels}
    data_per_label = {}
    for index, row in train_data.iterrows():
        words = preprocess(row['content'])
        label = row['label']
        if label not in data_per_label:
            data_per_label[label] = {}
        for word in make_ngrams(words, n):
            data_per_label[label][word] = data_per_label[label].get(word, 0) + 1
            total_data[label] += 1
    return total_data, data_per_label

# %%
import matplotlib.pyplot as plt
from operator import itemgetter
from bidi.algorithm import get_display
from arabic_reshaper import reshape

# %%
def plot_frequency_of_words(data_per_label, frequency=5):
    figure, axis = plt.subplots(nrows=len(labels), ncols=1, figsize=(20, 20), constrained_layout=True)
    figure.supxlabel('Words')
    figure.supylabel('Frequency')
    for i in range(len(labels)):
        frequent = dict(sorted(data_per_label[labels[i]].items(), key=itemgetter(1), reverse=True)[:frequency])
        keys = frequent.keys()
        values = frequent.values()
        axis[i].bar([get_display(reshape(key)) for key in keys], values)
        axis[i].set_title(get_display(reshape(labels[i])))
    plt.show()

# %% [markdown]
# <u>total_data</u> is storing number of words in each label.
#
# <u>data_per_label</u> is storing number of occurence of word x in each label.

# %%
model = fit()
model = {'total_data': model[0], 'data_per_label': model[1]}
plot_frequency_of_words(model['data_per_label'])

# %%
stop_words.update(['سال', 'ایران', 'کشور', 'گوش', 'ایسنا','دست', 'کار', 'قرار', 'گزارش'])

# %%
model = fit()
model = {'total_data': model[0], 'data_per_label': model[1]}
plot_frequency_of_words(model['data_per_label'])

# %% [markdown]
# <font size=4 color='#FFFFFF'> 2.2 Additive Smoothing<font>
#
# <font size=2 color='#FFFFFF'>
# If a word contains only one type of label, Naive Bayes will definitely choose that label as the answer, which might be wrong in some cases.
#
# When word $x$ doesn't appeared in Label $c$, $P(x|c) = 0$ which will result in $P(c|x) = 0$ and the Label won't be chosen as the answer because $log(0) = - \infty$ so the $ sum_{i=1}^{n} log(P(x_i | c)) $ will converge to $- \infty$ and never will be chosen as the Label. Using *Additive Smoothing* is a solution which associate the probability as follows:
#
# $$ \frac{Word Count + \alpha}{Total Words + \alpha.D} $$
#
# where $D$ is the number of distinct words in that category and $\alpha$ is the degree of smoothing. $\alpha = 0$ when we don't need it which associate the probability as follows:
#
# $$ \frac{Word Count}{Total Words}$$
#
# This will avoid the $- \infty$ since the fraction will never be equal to 0.
# <font>

# %%
import numpy as np

# %%
def calculate_score(data_per_label, total_data, ngrams, unique_ngrams, label, alpha):
    score = 0
    ZERO = (10)**(-100)
    for ngram in ngrams:
        if not ngram in data_per_label[label] and alpha == 0:
            score += np.log(ZERO)
        else:
            score += np.log((data_per_label[label].get(ngram, 0) + alpha) / (total_data[label] + alpha * len(unique_ngrams)))
    score += np.log(labels_frequency[label]/np.sum(labels_frequency))
    return score

# %%
def unique_words(ngrams):
    unique = list()
    for ngram in ngrams:
        if ngram not in unique:
            unique.append(ngram)
    return unique

# %%
def prediction(model, data, n=1, alpha=0):
    data_per_label = model['data_per_label']
    total_data = model['total_data']
    predictions = []
    for index, row in data.iterrows():
        words = preprocess(row['content'])
        ngrams = make_ngrams(words, n)
        unique_ngrams = unique_words(ngrams)
        max_score = -np.inf
        max_label = None
        for label in labels:
            scores = {label:calculate_score(data_per_label, total_data, ngrams, unique_ngrams, label, alpha)}
            if max(scores.values()) > max_score:
                max_score = max(scores.values())
                max_label = max(scores, key=scores.get)
        predictions.append(max_label)
    data['predicted_label'] = predictions
    
    return data

# %%
predicted = test_data
predicted = prediction(model, predicted)
predicted
# Out:
#             label                                            content  \
# 0          فناوری  بعد از اعلام لیست ۲۳ شرکت مجاز ثبت سفارش و ارا...
# 1     فرهنگی/هنری  یک استاد علم قرائت قرآن کریم، گفت: ریشه موسیقی...
# 2           حوادث  آتش سوزی های زنجیره ای جنگل های زاگرس در استان...
# 3          فناوری  استفاده از سرویس‌های iMassage یا Facetime محصو...
# 4           حوادث  دادستان عمومی و انقلاب یاسوج گفت: 10 میلیون دل...
# ...           ...                                                ...
# 1110        ورزشی  عضو هیات مدیره باشگاه استقلال گفت:من هیچوقت به...
# 1111        حوادث  مدیر آموزش و پرورش شهرستان جیرفت از دستگیری دا...
# 1112        سیاسی  رییس جمهور با بیان اینکه در هفته گذشته هیچ شهر...
# 1113       فناوری  دارندگان مدل‌های اعلام‌شده گوشی‌های هوآوی، می‌...
# 1114        سلامت  مطالعه ای جدید نشان داده است که احتمال مثبت بو...
#
#      predicted_label
# 0             فناوری
# 1        فرهنگی/هنری
# 2              حوادث
# 3             فناوری
# 4              حوادث
# ...              ...
# 1110           ورزشی
# 1111     فرهنگی/هنری
# 1112           سیاسی
# 1113          فناوری
# 1114           سلامت
#
# [1115 rows x 3 columns]

# %% [markdown]
# <font size=4 color='#FFFFFF'> 3. Evaluation<font>
#
# <font size=2 color='#FFFFFF'>
#
# 3.1 Consider the classifier will always predicts a specific class like "سیاسی" for a Label, the recall value for this specific class "سیاسی" will be 100% which definitely is not good! On the other hand, if we don't have enough predictions(e.g 2), the probability of making mistake in predictions would be so low because we made only 2 predictions. So the precision may lead to 100%.
#
# 3.2 F1 Score is the harmonic mean of Precision and Recall. F1 is usually more useful than accuracy, especially if there's a big difference between Precision and Recall. If false positives and false negatives have similar cost, Accuracy works better.
#
# $$F_{1} = 2\frac{Precision.Recall}{Precision + Recall} = \frac{TP}{TP + \frac{FP + FN}{2}}$$
#
# $$Precision = \frac{TP}{TP + FP}$$
#
# $$Recall = \frac{TP}{TP + FN}$$
# <font>
#
# <font size=1 color='#FFFFFF'> *P.S.* *TP* : *true positive*, *FP* : *false positive*, *FN* : *false negative* <font>
#
# <font size=2 color='#FFFFFF'>
#
# 3.3 Multi-Class Metrics
#
# **Micro**: Calculates F1 by value total true positives, false negatives and false positives. Prediction for each label in the dataset doesn't matter.
#
# $$Micro-F1 = \frac{CorrectDetected}{AllDetected}$$
#
# **Macro**: Calculates F1 for each label, and returns the average without considering the proportion for each label in the dataset.
#
# $$Macro-F1 = \frac{F1_1 + F1_2 + ... + F1_n}{n}$$
#
# When averaging the macro-F1, we gave equal weights to each class. We don’t have to do that: in weighted-F1, we weight the F1-score of each class by the number of samples from that class.
#
# **Weighted**: Calculates F1 for each label, and returns the average considering the proportion for each label in the dataset.
#
# $$Weighted-F1 = {P(C_1)F1_1+ ... + P(C_n)F1_n}$$
# <font>

# %%
def calculate(predicted):
    rows_name = ['Precision', 'Recall', 'F1-score', 'Accuracy', 'Macro Avg', 'Micro Avg', 'Weighted Avg']
    cols_name = np.append(labels,'All Classes')
    probability_table = pd.DataFrame(index=rows_name, columns=cols_name)
    F1 = {label: 0 for label in labels}
    weighted_avg = 0
    for label in labels:
        total_class = 0
        correct_detected_class = 0
        all_detected_class = 0
        for index, row in predicted.iterrows():
            if row['label'] == label:
                total_class += 1
            if row['label'] == label and row['predicted_label'] == label:
                correct_detected_class += 1
            if row['predicted_label'] == label:
                all_detected_class += 1

        precision = correct_detected_class / all_detected_class
        recall = correct_detected_class / total_class
        F1[label] = (2 * precision * recall) / (precision + recall)
        
        weighted_avg += total_class / len(predicted) * F1[label]

        probability_table[label]['Precision'] = precision * 100
        probability_table[label]['Recall'] = recall * 100
        probability_table[label]['F1-score'] = F1[label] * 100
        
    total_corrected = predicted[predicted['label'] == predicted['predicted_label']]
    probability_table['All Classes']['Accuracy'] = len(total_corrected) / len(predicted) * 100
    probability_table['All Classes']['Macro Avg'] = np.mean(list(F1.values())) * 100
    probability_table['All Classes']['Micro Avg'] = probability_table['All Classes']['Accuracy']
    probability_table['All Classes']['Weighted Avg'] = weighted_avg * 100
    probability_table.fillna('-', inplace=True)
    return probability_table

# %%
with_out_smoothing = prediction(model, test_data, n=1, alpha=0)
calculate(with_out_smoothing)
# Out:
#                  فناوری      ورزشی      حوادث      سلامت      سیاسی  \
# Precision     91.411043  98.235294  93.939394  94.674556  80.092593
# Recall        88.690476  87.894737       77.5   90.39548       86.5
# F1-score      90.030211  92.777778  84.931507  92.485549  83.173077
# Accuracy              -          -          -          -          -
# Macro Avg             -          -          -          -          -
# Micro Avg             -          -          -          -          -
# Weighted Avg          -          -          -          -          -
#
#              فرهنگی/هنری All Classes
# Precision      70.258621           -
# Recall         90.555556           -
# F1-score       79.126214           -
# Accuracy               -   86.726457
# Macro Avg              -   87.087389
# Micro Avg              -   86.726457
# Weighted Avg           -   86.983346

# %%
with_smoothing = prediction(model, test_data, n=1, alpha=1)
calculate(with_smoothing)
# Out:
#                  فناوری      ورزشی      حوادث      سلامت      سیاسی  \
# Precision     95.679012  99.459459  89.814815  97.109827       90.0
# Recall        92.261905  96.842105       97.0  94.915254       94.5
# F1-score      93.939394  98.133333  93.269231       96.0  92.195122
# Accuracy              -          -          -          -          -
# Macro Avg             -          -          -          -          -
# Micro Avg             -          -          -          -          -
# Weighted Avg          -          -          -          -          -
#
#              فرهنگی/هنری All Classes
# Precision      95.266272           -
# Recall         89.444444           -
# F1-score        92.26361           -
# Accuracy               -    94.26009
# Macro Avg              -   94.300115
# Micro Avg              -    94.26009
# Weighted Avg           -   94.277553

# %%
bigram_model = fit(n=2)
bigram_model = {'total_data': bigram_model[0], 'data_per_label': bigram_model[1]}
with_bigram = prediction(bigram_model, test_data, n=2, alpha=0)
calculate(with_bigram)
# Out:
#                  فناوری      ورزشی      حوادث      سلامت      سیاسی  \
# Precision     94.767442   97.87234  95.918367  95.530726  91.469194
# Recall         97.02381  96.842105       94.0  96.610169       96.5
# F1-score      95.882353  97.354497  94.949495  96.067416  93.917275
# Accuracy              -          -          -          -          -
# Macro Avg             -          -          -          -          -
# Micro Avg             -          -          -          -          -
# Weighted Avg          -          -          -          -          -
#
#              فرهنگی/هنری All Classes
# Precision      95.266272           -
# Recall         89.444444           -
# F1-score        92.26361           -
# Accuracy               -   95.067265
# Macro Avg              -   95.072441
# Micro Avg              -   95.067265
# Weighted Avg           -   95.058589

# %% [markdown]
# <font size=2 color='#FFFFFF'>
# As we see, using "Additive smoothing" has improved the estimation. <font>

# %%
wrong_predicted = predicted[predicted['label'] != predicted['predicted_label']]
wrong_predicted
# Out:
#             label                                            content  \
# 30    فرهنگی/هنری  - چهارشنبه اول تیر 1401 اتفاق نادر و جالبی رخ ...
# 45    فرهنگی/هنری  اعتراض گسترده کاربران توییتر به اظهارات وزیر ا...
# 65          حوادث  ملی‌پوش سابق دوچرخه سواری ایران به علت تصادف د...
# 85    فرهنگی/هنری  - روز گذشته در حاشیه معرفی ساپینتو سر مربی باش...
# 88          سلامت  وزیر بهداشت، طی نامه‌ای به معاون بهداشت این وز...
# 114         حوادث  کانون اصلی این زلزله در شمال شرق ایالت ویکتوری...
# 141   فرهنگی/هنری                                             عصرخبر
# 143        فناوری  در بحبوحه افزایش درخواست‌ها برای حذف تایم لاین...
# 149   فرهنگی/هنری  - دربارۀ 12 اردیبهشت ، روز معلم و سال‌روز ترور...
# 173   فرهنگی/هنری  رایج بلیت های خود را کمتر از یک دلار افزایش دا...
# 196         حوادث  یک مقام آمریکایی روز جمعه اعلام کرد که دستکم ی...
# 221         سیاسی  وزیر بهداشت گفت: مهمترین کار و اولویت وزارت به...
# 234         سیاسی  دبیر اجرایی کمیسیون نظارت عمومی مسکو (ONK) روز...
# 253         سیاسی  حکم عوامل حمله تروریستی سال ۱۳۹۶ به کلانتری کو...
# 276   فرهنگی/هنری  مردي صبح از خواب بيدار شد و ديد تبرش ناپديد شد...
# 321         حوادث  مدیر واحد مدل‌سازی و پیش‌بینی شرکت کنترل کیفیت...
# 322         سلامت  رئیس دانشگاه علوم پزشکی خراسان شمالی گفت: میزا...
# 446         سیاسی  سخنگوی کرملین امروز (سه شنبه) با اشاره به برنا...
# 462   فرهنگی/هنری                                             عصرخبر
# 517         حوادث  - قهرمان سابق بدنسازی جهان  و ستاره هالیوود در...
# 526   فرهنگی/هنری  خانواده «هالینا هاچینز» فیلمبردار کشته شده در ...
# 538         ورزشی  آنتونی استوکس به دلیل مزاحمت برای همسر سابق خو...
# 547   فرهنگی/هنری  پیش نویس خواهر خواندگی شهرهای صعده یمن و دزفول...
# 549         ورزشی  افزایش تولید و توزیع داروها و مکمل‌های تقلبی د...
# 601   فرهنگی/هنری  یک مرد ۴۱ ساله با حمله و آتش زدن استودیو انیمی...
# 611         ورزشی  عادل فردوسی‌پور کینگ کُنگ فوتبال ماست. مثل او ...
# 668         حوادث  سارق اموال داخل خودروها در لحظه آزادی از زندان...
# 716         حوادث  یک بازیگر روس بر اثر افتادن دکورهای صحنه به هن...
# 742         حوادث  وزارت دادگستری تاجیکستان امروز (دوشنبه) اعلام ...
# 745         حوادث  منبع تصاویر: عصر ایران، کانال روزنامه البرز فر...
# 753   فرهنگی/هنری                                             : مشرق
# 760   فرهنگی/هنری  محمد خدادی درباره راهکار‌های خود برای ساماندهی...
# 818         ورزشی  تازه‌ترین فعالیت جواد خیابانی در عرصه گویندگی ...
# 836         سلامت  قائم‌مقام وزیر بهداشت با بیان اینکه روند ابتلا...
# 846         ورزشی  رئیس هیات زورخانه و پهلوانی استان تهران اعلام ...
# 879         حوادث  گارد ساحلی فرانسه روز یکشنبه اعلام کرد که قایق...
# 883         سلامت  سخنگوی کمیسیون اصل نود مجلس شورای اسلامی گفت ک...
# 898   فرهنگی/هنری  دفتر موسیقی از تعطیلی کنسرت‌ها در سه روز عزای ...
# 900   فرهنگی/هنری  ثبت نام برای شرکت در آزمون کارشناسی ارشد دوره ...
# 927         ورزشی  با وجود اینکه سال‌های زیادی از مرگ جهان‌پهلوان...
# 928         حوادث  به دنبال گزارش مشاهده مار در یکی از خوابگاه‌ها...
# 959         حوادث  منابع امنیتی تایید کرده‌اند که در حمله انتحاری...
# 961        فناوری  رئیس مرکز ملی تحقیقات و مطالعات باروری ابرها گ...
# 972         سیاسی  معاون اول قوه قضاییه در برنامه دستخط با اشاره ...
# 987         سلامت  وزیر بهداشت با اشاره به اقدامات انجام شده در ج...
# 998   فرهنگی/هنری  رضا گلزار در گوش رئیس‌جمهور گفت: امروز ثابت کر...
# 1000       فناوری  محققان موفق به توسعه یک بازی مبتنی بر اپلیکیشن...
# 1019        سیاسی  منابع امنیتی به خبرگزاری فرانسه گفتند، پنج عرا...
# 1033        سلامت  رئیس دانشگاه علوم پزشکی قم گفت: در حال حاضر حد...
# 1047        سیاسی  دفتر مطبوعاتی لشکر «۲۰۹» شاهین در شمال افغانست...
# 1066       فناوری  این روزها واقعا سخت است که بخواهیم چشم‌مان را ...
# 1068  فرهنگی/هنری  فیلمی از لحظه سجده شکر پرویز فتاح به دلیل مشار...
# 1082  فرهنگی/هنری  رضا کیانیان در صفحه شخصی خود در اینستاگرام با ...
# 1102  فرهنگی/هنری  بودجه صداوسیما صرف پرسنل می‌شود نه تولید! رسان...
# 1107       فناوری  به گزارش ایسنا و به نقل از سی نت، کنفرانس سالی...
#
#      predicted_label
# 30             سیاسی
# 45            فناوری
# 65             ورزشی
# 85             ورزشی
# 88             سیاسی
# 114           فناوری
# 141           فناوری
# 143            سیاسی
# 149            سیاسی
# 173           فناوری
# 196            سیاسی
# 221            سلامت
# 234      فرهنگی/هنری
# 253            حوادث
# 276            حوادث
# 321            سلامت
# 322            حوادث
# 446            ورزشی
# 462           فناوری
# 517            سلامت
# 526            حوادث
# 538            حوادث
# 547            سیاسی
# 549            سلامت
# 601            حوادث
# 611      فرهنگی/هنری
# 668      فرهنگی/هنری
# 716      فرهنگی/هنری
# 742            سیاسی
# 745           فناوری
# 753           فناوری
# 760            سیاسی
# 818      فرهنگی/هنری
# 836            سیاسی
# 846      فرهنگی/هنری
# 879           فناوری
# 883            سیاسی
# 898            سیاسی
# 900           فناوری
# 927      فرهنگی/هنری
# 928            سلامت
# 959            سیاسی
# 961            سیاسی
# 972      فرهنگی/هنری
# 987            سیاسی
# 998            سیاسی
# 1000           سلامت
# 1019           ورزشی
# 1033           حوادث
# 1047           حوادث
# 1066           سلامت
# 1068           سیاسی
# 1082           سیاسی
# 1102           سیاسی
# 1107           سلامت

# %% [markdown]
# <font size=2 color='#FFFFFF'> As we see content of the news is having words such as 'سازمان بهداشت جهانی','سرطان', 'بیماران and 'آزمایشات' which are mistaken with words in 'سلامت' Label. <font>

# %%
wrong_predicted[-1:]['content'].values[0]
# Out:
# 'به گزارش ایسنا و به نقل از سی نت، کنفرانس سالیانه گوگل(Google I/O ۲۰۱۹) که در آن از جدیدترین دستاوردهای نرم افزاری خود پرده برداری کرد شب گذشته (۹:۳۰ شب به وقت تهران) آغاز شد. گوگل طی "کنفرانس آ/او" (I / O) ۲۰۱۹ اعلام کرد که می\u200cخواهد فناوری هوش مصنوعی خود را برای تشخیص زود هنگام سرطان مورد استفاده قرار دهد. دکتر "لیلی پنگ" (Lily Peng) طی این کنفرانس گفت: فناوری این شرکت می\u200cتواند به دانشمندان برای تشخیص علائم اولیه سرطان کمک کند. طبق گزارش "سازمان بهداشت جهانی"، سرطان ریه شایع\u200cترین دلیل مرگ و میر مربوط به سرطان در بین زنان و مردان به\u200cشمار می\u200cرود و سالانه بیش از ۲ میلیون نفر در جهان به آن مبتلا می\u200cشوند. پنگ در ادامه افزود: در بیش از ۸۰ درصد موارد ما نمی\u200cتوانیم علائم اولیه سرطان را در بیماران مبتلا به سرطان ریه تشخیص دهیم اما اکنون هوش مصنوعی به کمک ما آمده است و توسط آن می\u200cتوانیم از مرگ زودرس افراد جلوگیری کنیم. \xa0 تشخیص علائم اولیه سرطان توسط سی\u200c.تی اسکن بسیار سخت است و سی\u200cتی اسکن تنها می\u200cتواند علائم سرطان بیمارانی که مدتی از سرطان آنها گذشته است را نشان دهد. \xa0 گوگل با استفاده از اسکن\u200cهای سرطان ریه "مؤسسه ملی سرطان" (National Cancer Institute) و "دانشگاه نورث وسترن" (Northwestern University)، موفق به توسعه یک شبکه عصبی برای تشخیص علائم اولیه سرطان و شدت بدخیمی آن شد. این کاری است که فراتر از توانایی\u200cهای یک رادیولوژیست است. طی این آزمایشات، یک فرد بدون علائم و بدون سابقه سرطان سی\u200cتی اسکن شد و نتیجه آن نرمال بود. \xa0 یک سال بعد، یک اسکن دیگر، ابتلاء به سرطان را در آن فرد نشان داد و در نهایت پژوهشگران از هوش مصنوعی گوگل استفاده کردند و هوش مصنوعی نیز اسکن اولیه فرد را مورد بررسی قرار داد و توانست نشانه\u200cهای اولیه سرطان را در فرد شناسایی کند. تشخیص زود هنگام سرطان می\u200cتواند میزان بقای افراد را تا ۴۰ درصد افزایش دهد.'
